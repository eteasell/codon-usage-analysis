# %%
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))

import pandas as pd
import matplotlib.pyplot as plt

path = '../data/dependent_hydrophobic_genes.csv'
df = pd.read_csv(path, index_col='gene')
print(df)

start = df['first_hydrophobic_start']
end = df['first_hydrophobic_end']
lengths = end - start
# Out:
#          length     sp   tmd  first_hydrophobic_start  first_hydrophobic_end
# gene
# YAL042W     415  False  True                     25.0                   45.0
# YAL007C     215   True  True                      1.0                   25.0
# YAR027W     235  False  True                     51.0                   68.0
# YAR028W     234  False  True                     51.0                   68.0
# YAR033W     234  False  True                     51.0                   68.0
# ...         ...    ...   ...                      ...                    ...
# YPR117W    2489  False  True                     15.0                   26.0
# YPR138C     489  False  True                     19.0                   42.0
# YPR149W     173  False  True                      4.0                   24.0
# YPR198W     543  False  True                      9.0                   29.0
# YPR201W     404  False  True                     35.0                   55.0
#
# [344 rows x 5 columns]

# %%
plt.hist(end, bins=30, edgecolor='black')
plt.xlabel('SP/TMD End Position')
plt.ylabel('Frequency')
plt.title('SP/TMD End Positions in SRP-dependent Proteins')
plt.show()

# %%
plt.hist(lengths, edgecolor='black')
plt.xlabel('Length of SP/TMD (amino acids)')
plt.ylabel('Frequency')
plt.title('SP/TMD Lengths in SRP-dependent Proteins')
plt.show()
